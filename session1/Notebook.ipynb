# %% [markdown]
# ### Simulation Based Inference
#
# #### Exercises Session 1
#
# ##### Lorenzo Consoli

# %% [markdown]
# Importing the objects and the necessary libraries

# %%
from StateSpaceModels.StochasticVolatility import *
from StateSpaceModels.BassModel import *
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Exercise 1
#
# Simulate a Stochastic Volatility model in python

# %%
state_space_model = StochasticVolatility()

# %%
state_space_model.run_simulation()

# %%
plt.plot(state_space_model.observation_history)

# %%
plt.plot(np.exp(state_space_model.latent_variables_history))
